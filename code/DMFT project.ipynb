# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,a,b):
    
    return a*x+b

# %%
def approxderiv(X,Y):  #fit on 3 points to get the approx derivative
    popt,pcov=spo.curve_fit(f,X,Y)
    return popt[0]

# %%
#J=0 , 1 mean D1=1 , 2 mean D2=2
Sigma1_0=[]
Sigma2_0=[]
U=[0,1,2,3,4,5,6,7]
Matsu=[]
for j in range(len(U)):
    List1=[]
    List2=[]
    Ma=[]
    filename=r"C:\Users\pttai\Desktop\M2\Electronic structure theory\projet DMFT\Data\J0\U"+str(j)+"\Sigma"+str(j)+".dat"
    file = open(filename,'r')
    for L in file.readlines():
        L=L.split('\t')
        Ma.append(float(L[0]))
        List1.append(float(L[2]))
        List2.append(float(L[8]))
    Matsu.append(Ma)    
    Sigma1_0.append(List1)
    Sigma2_0.append(List2)
    file.close()

# %%
plt.figure(figsize=(12,8))
plt.plot(Matsu[0],Sigma1_0[-5],label='D1=1',marker='o')
plt.plot(Matsu[0],Sigma2_0[-5],label='D2=2',marker='o')
plt.legend()
plt.show()

# %%
Z1_0=[]
Z2_0=[]
for j in range(len(U)):
    a1=(Sigma1_0[j][1]-Sigma1_0[j][0])/(Matsu[0][1]-Matsu[0][0])
    a2=(Sigma2_0[j][1]-Sigma2_0[j][0])/(Matsu[0][1]-Matsu[0][0])
    Z1_0.append(1/(1-a1))
    Z2_0.append(1/(1-a2))
for j in range(len(U)):
    Z1_0[j]=Z1_0[j]/max(Z1_0)
    Z2_0[j]=Z2_0[j]/max(Z2_0)
    
    
print(Z1_0[-1])
print(Z2_0[-1])
# Out:
# -0.04232433908704414
# -0.041193313536944914

# %%
fig=plt.figure(figsize=(14,8))
ax=fig.gca()
plt.plot(U,Z1_0,label='D1=1',marker='o')
plt.plot(U,Z2_0,label='D2=2',marker='o')
#plt.plot(U,[Z2_0[i]-Z1_0[i] for i in range(len(U))])
plt.legend()
plt.grid()
ax.set_xticks(np.arange(0, 7, 0.2))

plt.xlabel('U')
plt.ylabel('Z')
plt.show()

# %%
#J=0.25 , 1 mean D1=1 , 2 mean D2=2
Sigma1_025=[]
Sigma2_025=[]
U25=[0,1,2,3,4,5]

for j in range(len(U25)):
    List1=[]
    List2=[]
    
    filename=r"C:\Users\pttai\Desktop\M2\Electronic structure theory\projet DMFT\Data\J025\U"+str(j)+"\Sigma"+str(j)+".dat"
    file = open(filename,'r')
    for L in file.readlines():
        L=L.split('\t')
        Ma.append(float(L[0]))
        List1.append(float(L[2]))
        List2.append(float(L[8]))
    Matsu.append(Ma)    
    Sigma1_025.append(List1)
    Sigma2_025.append(List2)
    file.close()

# %%
Z1_025=[]
Z2_025=[]
for j in range(len(U25)):
    a1=(Sigma1_025[j][1]-Sigma1_025[j][0])/(Matsu[0][1]-Matsu[0][0])
    a2=(Sigma2_025[j][1]-Sigma2_025[j][0])/(Matsu[0][1]-Matsu[0][0])
    Z1_025.append(1/(1-a1))
    Z2_025.append(1/(1-a2))
for j in range(len(U25)):
    Z1_025[j]=Z1_025[j]/max(Z1_025)
    Z2_025[j]=Z2_025[j]/max(Z2_025)
    
    
print(Z1_025[-1])
print(Z2_025[-1])
# Out:
# -0.005159573668576204
# -0.013216346809476184

# %%
fig=plt.figure(figsize=(14,8))
ax=fig.gca()
plt.plot(U25,Z1_025,label='D1=1',marker='o')
plt.plot(U25,Z2_025,label='D2=2',marker='o')
#plt.plot(U,[Z2_0[i]-Z1_0[i] for i in range(len(U))])
plt.legend()
plt.grid()
ax.set_xticks(np.arange(0, 5.6, 0.2))
plt.xlabel('U')
plt.ylabel('Z')
plt.show()

# %%
#J=0.1 , 1 mean D1=1 , 2 mean D2=2
Sigma1_01=[]
Sigma2_01=[]
U1=[0,1,2,3,4,5,6]

for j in range(len(U1)):
    List1=[]
    List2=[]
    
    filename=r"C:\Users\pttai\Desktop\M2\Electronic structure theory\projet DMFT\Data\J01\U"+str(j)+"\Sigma"+str(j)+".dat"
    file = open(filename,'r')
    for L in file.readlines():
        L=L.split('\t')
        Ma.append(float(L[0]))
        List1.append(float(L[2]))
        List2.append(float(L[8]))
    Matsu.append(Ma)    
    Sigma1_01.append(List1)
    Sigma2_01.append(List2)
    file.close()

# %%
Z1_01=[]
Z2_01=[]
for j in range(len(U1)):
    a1=(Sigma1_01[j][1]-Sigma1_01[j][0])/(Matsu[0][1]-Matsu[0][0])
    a2=(Sigma2_01[j][1]-Sigma2_01[j][0])/(Matsu[0][1]-Matsu[0][0])
    Z1_01.append(1/(1-a1))
    Z2_01.append(1/(1-a2))
for j in range(len(U1)):
    Z1_01[j]=Z1_01[j]/max(Z1_01)
    Z2_01[j]=Z2_01[j]/max(Z2_01)
    
    
print(Z1_01[-1])
print(Z2_01[-1])
# Out:
# -0.11390633121704925
# -0.027572649421420778

# %%
fig=plt.figure(figsize=(14,8))
ax=fig.gca()
plt.plot(U1,Z1_01,label='D1=1',marker='o')
plt.plot(U1,Z2_01,label='D2=2',marker='o')
#plt.plot(U,[Z2_0[i]-Z1_0[i] for i in range(len(U))])
plt.legend()
plt.grid()
ax.set_xticks(np.arange(0, 6, 0.2))
plt.xlabel('U')
plt.ylabel('Z')
plt.show()

# %%
#J=0.2 , 1 mean D1=1 , 2 mean D2=2
Sigma1_02=[]
Sigma2_02=[]
U2=[0,1,2,3,4,5]

for j in range(len(U2)):
    List1=[]
    List2=[]
    
    filename=r"C:\Users\pttai\Desktop\M2\Electronic structure theory\projet DMFT\Data\J02\U"+str(j)+"\Sigma"+str(j)+".dat"
    file = open(filename,'r')
    for L in file.readlines():
        L=L.split('\t')
        Ma.append(float(L[0]))
        List1.append(float(L[2]))
        List2.append(float(L[8]))
    Matsu.append(Ma)    
    Sigma1_02.append(List1)
    Sigma2_02.append(List2)
    file.close()

# %%
Z1_02=[]
Z2_02=[]
for j in range(len(U2)):
    a1=(Sigma1_02[j][1]-Sigma1_02[j][0])/(Matsu[0][1]-Matsu[0][0])
    a2=(Sigma2_02[j][1]-Sigma2_02[j][0])/(Matsu[0][1]-Matsu[0][0])
    Z1_02.append(1/(1-a1))
    Z2_02.append(1/(1-a2))
for j in range(len(U2)):
    Z1_02[j]=Z1_02[j]/max(Z1_02)
    Z2_02[j]=Z2_02[j]/max(Z2_02)

# %%
fig=plt.figure(figsize=(14,8))
ax=fig.gca()
plt.plot(U2,Z1_02,label='D1=1',marker='o')
plt.plot(U2,Z2_02,label='D2=2',marker='o')
#plt.plot(U,[Z2_0[i]-Z1_0[i] for i in range(len(U))])
plt.legend()
plt.grid()
ax.set_xticks(np.arange(0, 5, 0.2))
plt.xlabel('U')
plt.ylabel('Z')
plt.show()

# %%
J=[0,0.25,0.1,0.2]
Uc1=[6.7,3.95,4.9,3.9]
Uc2=[6.7,4.95,5.9,4.85]
Uprimec1=[Uc1[j]-2*J[j] for j in range(len(J))]
Uprimec2=[Uc2[j]-2*J[j] for j in range(len(J))]
DeltaUc=[np.abs(Uc2[j]-Uc1[j]) for j in range(len(Uc1))]
print(Uprimec1)
# Out:
# [6.7, 3.45, 4.7, 3.5]

# %%
plt.figure(figsize=(12,8))
plt.scatter(J,Uc1,label='Critical 1')
plt.scatter(J,Uc2,label='Critical 2')
plt.xlabel('Uprime')
plt.ylabel('U')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(J,DeltaUc)

plt.xlabel('J')
plt.ylabel('$ \Delta Uc$')
plt.legend()
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.
